# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('../data/raw_car_data.csv')

# %%
display('Null Values Count', df.isnull().sum())
display('Shape', df.shape)
display('info', df.info())
display(df.head())
# Out:
# 'Null Values Count'
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64
# 'Shape'
# (6019, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
# Name                 6019 non-null object
# Location             6019 non-null object
# Year                 6019 non-null int64
# Kilometers_Driven    6019 non-null int64
# Fuel_Type            6019 non-null object
# Transmission         6019 non-null object
# Owner_Type           6019 non-null object
# Mileage              6017 non-null object
# Engine               5983 non-null object
# Power                5983 non-null object
# Seats                5977 non-null float64
# New_Price            824 non-null object
# Price                6019 non-null float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 611.4+ KB
# 'info'
# None
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# 2  8.61 Lakh   4.50
# 3        NaN   6.00
# 4        NaN  17.74

# %%
#New_Price column is ~5/6 null values, dropping column. 
df = df.drop(columns=['New_Price'])

# %%
df1 = df[df.isna().any(axis=1)]
df1
df1.count()
# Out:
# Name                 44
# Location             44
# Year                 44
# Kilometers_Driven    44
# Fuel_Type            44
# Transmission         44
# Owner_Type           44
# Mileage              42
# Engine                8
# Power                 8
# Seats                 2
# Price                44
# dtype: int64

# %%
#Only 44 records with null values, dropping rows.
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5975 entries, 0 to 6018
# Data columns (total 12 columns):
# Name                 5975 non-null object
# Location             5975 non-null object
# Year                 5975 non-null int64
# Kilometers_Driven    5975 non-null int64
# Fuel_Type            5975 non-null object
# Transmission         5975 non-null object
# Owner_Type           5975 non-null object
# Mileage              5975 non-null object
# Engine               5975 non-null object
# Power                5975 non-null object
# Seats                5975 non-null float64
# Price                5975 non-null float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 606.8+ KB

# %%
#power (bhp), engine (cc), mileage (kmpl) should be int values
df.rename(columns={'Power': 'Power-bhp', 'Engine': 'Engine-cc', 'Mileage': 'Mileage-kmpl'}, inplace=True)

# %%
df['Power-bhp'] = df['Power-bhp'].str.replace('bhp', '')
df['Engine-cc'] = df['Engine-cc'].str.replace('cc', '')
df['Mileage-kmpl'] = df['Mileage-kmpl'].str.replace('kmpl', '')

# %%
df['Engine-cc'] = df['Engine-cc'].str.replace('CC', '')
df['Power-bhp'] = df['Power-bhp'].str.replace(' ', '')
df['Mileage-kmpl'] = df['Mileage-kmpl'].str.replace('km/kg', '')

# %%
df['Engine-cc'] = df['Engine-cc'].str.replace(' ', '')

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type Mileage-kmpl Engine-cc Power-bhp  Seats  \
# 0       CNG       Manual      First        26.6        998     58.16    5.0
# 1    Diesel       Manual      First       19.67       1582     126.2    5.0
# 2    Petrol       Manual      First        18.2       1199      88.7    5.0
# 3    Diesel       Manual      First       20.77       1248     88.76    7.0
# 4    Diesel    Automatic     Second        15.2       1968     140.8    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %%
df['Engine-cc'] = df['Engine-cc'].astype(int)

# %%
df['Mileage-kmpl'] = df['Mileage-kmpl'].astype(float)

# %%
df['Power-bhp'] = pd.to_numeric(df['Power-bhp'], errors='coerce')

# %%
display('describe', df.describe())
# Out:
# 'describe'
#               Year  Kilometers_Driven  Mileage-kmpl    Engine-cc    Power-bhp  \
# count  5975.000000       5.975000e+03   5975.000000  5975.000000  5872.000000
# mean   2013.386778       5.867431e+04     18.179408  1621.606695   113.276894
# std       3.247238       9.155851e+04      4.521801   601.036987    53.881892
# min    1998.000000       1.710000e+02      0.000000   624.000000    34.200000
# 25%    2012.000000       3.390800e+04     15.200000  1198.000000    75.000000
# 50%    2014.000000       5.300000e+04     18.160000  1493.000000    97.700000
# 75%    2016.000000       7.300000e+04     21.100000  1984.000000   138.100000
# max    2019.000000       6.500000e+06     33.540000  5998.000000   560.000000
#
#              Seats        Price
# count  5975.000000  5975.000000
# mean      5.278828     9.501647
# std       0.808959    11.205736
# min       0.000000     0.440000
# 25%       5.000000     3.500000
# 50%       5.000000     5.650000
# 75%       5.000000     9.950000
# max      10.000000   160.000000

# %%
df.rename(columns={'Owner_Type': 'Number_Owners'})
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Number_Owners  Mileage-kmpl  Engine-cc  Power-bhp  \
# 0          CNG       Manual         First         26.60        998      58.16
# 1       Diesel       Manual         First         19.67       1582     126.20
# 2       Petrol       Manual         First         18.20       1199      88.70
# 3       Diesel       Manual         First         20.77       1248      88.76
# 4       Diesel    Automatic        Second         15.20       1968     140.80
# ...        ...          ...           ...           ...        ...        ...
# 6014    Diesel       Manual         First         28.40       1248      74.00
# 6015    Diesel       Manual         First         24.40       1120      71.00
# 6016    Diesel       Manual        Second         14.00       2498     112.00
# 6017    Petrol       Manual         First         18.90        998      67.10
# 6018    Diesel       Manual         First         25.44        936      57.60
#
#       Seats  Price
# 0       5.0   1.75
# 1       5.0  12.50
# 2       5.0   4.50
# 3       7.0   6.00
# 4       5.0  17.74
# ...     ...    ...
# 6014    5.0   4.75
# 6015    5.0   4.00
# 6016    8.0   2.90
# 6017    5.0   2.65
# 6018    5.0   2.50
#
# [5975 rows x 12 columns]
